# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/vigneshk01/Gesture_Recognition_Case_Study/blob/master/Neural_Nets_Project_Starter_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://www.kaggle.com/code/vigneshk01/neural-nets-project-starter-code/edit"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %%
# Hyperparameters to tune
hp_epoch = 75  # 10, 30, 50
hp_lr = 0.01
hp_reducelr = 0.8  # 0.1
hp_batch_size = 64  # 32, 50 ,120
hp_x = hp_img_cnt = 25
hp_y = hp_z = 120
hp_loss = 'categorical_crossentropy' 
hp_metrics = ['categorical_accuracy']

# %% [markdown]
# # Environment Setup

# %%
# set env to 1 for direct download from gdrive, # 2 for mounting google drive, 3 for kaggle

env = 0 

# !pip install mlflow > _
# import mlflow
# mlflow.tensorflow.autolog()

import time
start_time = time.time()

if env == 1: ## Direct file download from drive
    # !gdown '1FoNRK7V0lLWf2ThyAq3TYU3kGakPBnn4' #download data file from gdrive
    # !unzip Project_data.zip > tmp #unzip the file,  "A" when prompted
    
elif env == 2: ## Mount google drive Instead
    from google.colab import drive, files
    drive.mount('/content/drive')
    drive_base = '/content/drive/MyDrive/Colab_Notebooks/projects/gesture_recognition' #project root dir

    # !cp -r -v {drive_base}/Project_data.zip /content #copy to temp drive
    # !cd /content/
    # !unzip Project_data.zip > extraction_log_dump #unzip the file,  "A" when prompted
    print('mounted and unpacked')
    # !ls -la /content/
    
elif env == 3:
    # !cp -r /kaggle/input/gesture-recogniton/Project_data/Project_data/ /kaggle/working/
    # data_path = '/kaggle/input/gesture-recogniton'
    # data_path = '/kaggle/input/gesture-recogniton/Project_data'
    
    data_path = '/kaggle/input/Project_data'
    print('files copied')
    # !ls -la /kaggle/input/Project_data
    
else:
    print("other env")
# Out:
# files copied
# total 0
# drwxr-xr-x 3 nobody nogroup 0 Feb  5 05:05 .
# drwxr-xr-x 3 nobody nogroup 0 Feb  5 05:05 ..
# drwxr-xr-x 4 nobody nogroup 0 Feb  5 05:05 Project_data

# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
import os
import cv2
import shutil
import glob 

import datetime
from re import L, match

import numpy as np
import random as rn
import matplotlib.pyplot as plt

from distutils.file_util import write_file
import warnings
warnings.filterwarnings('ignore')

from skimage.io import imread
from skimage.transform import resize
from skimage.morphology import dilation

import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import optimizers
from tensorflow.keras import backend as K
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import CSVLogger, EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Conv3D, Dense  
from tensorflow.keras.layers import Dropout, Flatten, GRU, Input, MaxPooling3D
from tensorflow.keras.layers import TimeDistributed, LeakyReLU, SpatialDropout3D
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers.schedules import ExponentialDecay, PolynomialDecay

print(keras.__version__) # '3.8.0'
print(tf.__version__) # '2.17.0'

print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
print(tf.config.list_physical_devices('GPU'))
# Out:
# 3.5.0
# 2.17.1
# Num GPUs Available:  1
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
rn.seed(30) 
tf.random.set_seed(30)
keras.utils.set_random_seed(30)

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
if env ==3:
    train_doc = np.random.permutation(open(data_path + '/Project_data/train.csv').readlines())
    val_doc = np.random.permutation(open(data_path + '/Project_data/val.csv').readlines())
else:
    train_doc = np.random.permutation(open('./Project_data/train.csv').readlines())
    val_doc = np.random.permutation(open('./Project_data/val.csv').readlines())
batch_size = hp_batch_size

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
def crop_image(img):  # this cropping approach tries to generate a grayscale image from original image and then tries to find contours, From the contours, it tries to select the contour that has maximum area, and tries to crop it
    img2cv = img.astype(np.uint8)
    img_rgb = cv2.cvtColor(img2cv, cv2.COLOR_BGR2RGB)
    gray_img = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2GRAY)
    
    _, binary_img = cv2.threshold(gray_img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    contours_mat, _ = cv2.findContours(binary_img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # img_sobel = cv2.Sobel(gray_img, cv2.CV_64F, 1, 0, ksize=5)
    # img_canny = cv2.Canny(img,100,200)
    # img_guss = cv2.GaussianBlur(binary_img,(5,5),0)
    
    # kernel1 = np.ones((3, 3), np.uint8)
    # img_dil = dilation(binary_img, kernel1)
    # img_ero = cv2.erode(binary_img, kernel1, iterations = 1)
    # img_ope = cv2.morphologyEx(binary_img, cv2.MORPH_OPEN, kernel1)
    # img_clo = cv2.morphologyEx(binary_img, cv2.MORPH_CLOSE, kernel1)

    hulls = []
    for i in range(len(contours_mat)):
        hulls.append(cv2.convexHull(contours_mat[i]))
        
    if len(hulls) > 0:
        contours_sorted = sorted(hulls, key=lambda x: cv2.contourArea(x), reverse=True)
        selected_contour = contours_sorted[0]
        
        x, y, w, h = cv2.boundingRect(selected_contour)
        cropped_image = img[y:y+h, x:x+w]
        return cropped_image
    else:
        return img

# %%
def generator(source_path, folder_list, batch_size):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    img_idx = rn.sample(range(0,30), hp_img_cnt) #creates a list of image numbers to use for a particular video
    
    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(folder_list)//batch_size # calculates the number of batches
        remaining_sequences = len(folder_list)%batch_size
        x = len(img_idx)
        z , y = hp_z, hp_y

        for batch in range(num_batches): #  iterate over the number of batches
            batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterates over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx, item in enumerate(img_idx): #  Iterat the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

                    #crop the images
                    image = image[25:-25,25:-25]
                    # image = crop_image(image)
                    
                    #resize the image to 120x120
                    image = resize(image, (y,z)) 
                    normalized_img = image/255

                    batch_data[folder,idx,:,:,0] = normalized_img[:,:,0] #normalize and feed in the image
                    batch_data[folder,idx,:,:,1] = normalized_img[:,:,1] #normalize and feed in the image
                    batch_data[folder,idx,:,:,2] = normalized_img[:,:,2] #normalize and feed in the image

                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels # yields the batch_data and the batch_labels


        # code for the remaining sequences which are left after full batches
        if remaining_sequences > 0:
            batch = num_batches
            batch_data = np.zeros((remaining_sequences,x,y,z,3)) # x is the number of images for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((remaining_sequences,5)) # batch_labels is the one hot representation of the output
                
            for folder in range(remaining_sequences):
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx, item in enumerate(img_idx): #  Iterate the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

                    #crop the images  
                    image = image[25:-25,25:-25]
                    
                    #resize the image to 120x120
                    image = resize(image, (y,z))
                    normalized_img = image/255

                    batch_data[folder,idx,:,:,0] = normalized_img[:,:,0] #normalize and feed in the image
                    batch_data[folder,idx,:,:,1] = normalized_img[:,:,1] #normalize and feed in the image
                    batch_data[folder,idx,:,:,2] = normalized_img[:,:,2] #normalize and feed in the image

                    batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels # yields the batch_data and the batch_labels

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = './Project_data/train'
val_path = './Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)

num_epochs = hp_epoch # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 75

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
# Sequential groups a linear stack of layers into a Model.

model = Sequential()
model.add(Input(shape=(hp_x, hp_y, hp_z, 3)))

model.add(Conv3D(16, (2,2,2), activation='elu')) # elu, relu
model.add(BatchNormalization())
model.add(MaxPooling3D(pool_size=2))

model.add(Conv3D(32, (2,2,2), activation='elu')) # elu, relu
model.add(BatchNormalization())
model.add(MaxPooling3D(pool_size=2))

model.add(Conv3D(64, (2,2,2), activation='elu')) # elu, relu
model.add(BatchNormalization())
model.add(MaxPooling3D(pool_size=2))
model.add(Dropout(0.3))
# model.add(SpatialDropout3D(0.3))

model.add(Flatten())
# model.add(Dense(units=256, activation="elu")) # elu, relu
model.add(Dense(units=128, activation='elu')) # Densely connected layer
# model.add(Dense(units=64, activation="elu"))
# model.add(Dense(units=32, activation="elu"))

model.add(Dropout(0.3)) # Dropout randomly sets input units to 0
model.add(Dense(5, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv3d (Conv3D)                      │ (None, 24, 119, 119, 16)    │             400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 24, 119, 119, 16)    │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d (MaxPooling3D)         │ (None, 12, 59, 59, 16)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv3d_1 (Conv3D)                    │ (None, 11, 58, 58, 32)      │           4,128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 11, 58, 58, 32)      │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d_1 (MaxPooling3D)       │ (None, 5, 29, 29, 32)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv3d_2 (Conv3D)                    │ (None, 4, 28, 28, 64)       │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 4, 28, 28, 64)       │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d_2 (MaxPooling3D)       │ (None, 2, 14, 14, 64)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 2, 14, 14, 64)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       3,211,392 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 5)                   │             645 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,233,461 (12.33 MB)
#  Trainable params: 3,233,237 (12.33 MB)
#  Non-trainable params: 224 (896.00 B)

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
# lr_schedule = ExponentialDecay(hp_lr, num_train_sequences//batch_size, 0.09, staircase=False, name="ExponentialDecay") # exponential decay schedule
# lr_schedule = PolynomialDecay(hp_lr, num_train_sequences//batch_size, 0.00001, power=0.5) # polynomial decay schedule.

optimizer = optimizers.Adam(learning_rate = hp_lr) # Adam - Adaptive estimation of first-order and second-order moments
# optimizer = optimizers.SGD(learning_rate = hp_lr) # SGD - Gradient descent (with momentum) optimizer
# optimizer = optimizers.Adam(learning_rate = lr_schedule) 
# Model configuration
model.compile(optimizer=optimizer, loss=hp_loss, metrics=hp_metrics)

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
if env ==3:
    train_path = data_path+'/Project_data/train'
    val_path = data_path+'/Project_data/val'

# Instantiate the generators
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'

if not os.path.exists(model_name):
    os.mkdir(model_name)

filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.keras'

# ModelCheckpoint - To save the model after every epoch
checkpoint = ModelCheckpoint(filepath, monitor='val_categorical_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', save_freq='epoch')

# ReduceLROnPlateau - Reduce learning rate when there is no change in val_loss
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=hp_reducelr, patience=5, min_lr=0.0001) # write the REducelronplateau code here

# EarlyStopping - Stop training when val_loss has stopped decreasing
early_stop = EarlyStopping(monitor='val_categorical_accuracy', patience=10, mode=max, verbose=1, start_from_epoch=1)

# CSVLogger - log epoch results in a csv
csv_logger = CSVLogger('training.csv', separator=",", append=True)

callbacks_list = [checkpoint, reduce_lr, early_stop, csv_logger]

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
# Train the model
model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
          callbacks=callbacks_list, validation_data=val_generator, validation_steps=validation_steps,
          class_weight=None, initial_epoch=0)
# Out:
# Source path =  /kaggle/input/Project_data/Project_data/train ; batch size = 64
# Epoch 1/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - categorical_accuracy: 0.3022 - loss: 35.7290 Source path =  /kaggle/input/Project_data/Project_data/val ; batch size = 64
#
# Epoch 1: val_categorical_accuracy improved from -inf to 0.18000, saving model to model_init_2025-02-1007_31_04.764953/model-00001-32.98415-0.30769-156.09605-0.18000.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 210s 20s/step - categorical_accuracy: 0.3027 - loss: 35.5002 - val_categorical_accuracy: 0.1800 - val_loss: 156.0961 - learning_rate: 0.0100
# Epoch 2/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - categorical_accuracy: 0.3475 - loss: 4.6337
# Epoch 2: val_categorical_accuracy improved from 0.18000 to 0.19000, saving model to model_init_2025-02-1007_31_04.764953/model-00002-4.33726-0.31825-28.79457-0.19000.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 114s 11s/step - categorical_accuracy: 0.3451 - loss: 4.6090 - val_categorical_accuracy: 0.1900 - val_loss: 28.7946 - learning_rate: 0.0100
# Epoch 3/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.3138 - loss: 2.7388
# Epoch 3: val_categorical_accuracy improved from 0.19000 to 0.23000, saving model to model_init_2025-02-1007_31_04.764953/model-00003-2.84500-0.30468-106.27803-0.23000.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 124s 12s/step - categorical_accuracy: 0.3130 - loss: 2.7477 - val_categorical_accuracy: 0.2300 - val_loss: 106.2780 - learning_rate: 0.0100
# Epoch 4/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.3748 - loss: 2.0525
# Epoch 4: val_categorical_accuracy did not improve from 0.23000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 129s 12s/step - categorical_accuracy: 0.3732 - loss: 2.0657 - val_categorical_accuracy: 0.1900 - val_loss: 47.5600 - learning_rate: 0.0100
# Epoch 5/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.3592 - loss: 1.6478
# Epoch 5: val_categorical_accuracy improved from 0.23000 to 0.24000, saving model to model_init_2025-02-1007_31_04.764953/model-00005-1.86611-0.33032-17.61297-0.24000.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 130s 12s/step - categorical_accuracy: 0.3568 - loss: 1.6660 - val_categorical_accuracy: 0.2400 - val_loss: 17.6130 - learning_rate: 0.0100
# Epoch 6/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.3201 - loss: 1.6880
# Epoch 6: val_categorical_accuracy did not improve from 0.24000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 129s 12s/step - categorical_accuracy: 0.3199 - loss: 1.6897 - val_categorical_accuracy: 0.2400 - val_loss: 8.4642 - learning_rate: 0.0100
# Epoch 7/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.4037 - loss: 1.4186
# Epoch 7: val_categorical_accuracy improved from 0.24000 to 0.25000, saving model to model_init_2025-02-1007_31_04.764953/model-00007-1.46478-0.37104-15.65805-0.25000.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 130s 12s/step - categorical_accuracy: 0.4009 - loss: 1.4224 - val_categorical_accuracy: 0.2500 - val_loss: 15.6581 - learning_rate: 0.0100
# Epoch 8/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.3667 - loss: 1.4728
# Epoch 8: val_categorical_accuracy improved from 0.25000 to 0.30000, saving model to model_init_2025-02-1007_31_04.764953/model-00008-1.47721-0.36501-6.79036-0.30000.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 135s 12s/step - categorical_accuracy: 0.3666 - loss: 1.4732 - val_categorical_accuracy: 0.3000 - val_loss: 6.7904 - learning_rate: 0.0100
# Epoch 9/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.4229 - loss: 1.3541
# Epoch 9: val_categorical_accuracy improved from 0.30000 to 0.36000, saving model to model_init_2025-02-1007_31_04.764953/model-00009-1.39075-0.42081-5.21284-0.36000.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 129s 12s/step - categorical_accuracy: 0.4227 - loss: 1.3572 - val_categorical_accuracy: 0.3600 - val_loss: 5.2128 - learning_rate: 0.0100
# Epoch 10/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.4150 - loss: 1.4227
# Epoch 10: val_categorical_accuracy did not improve from 0.36000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 131s 12s/step - categorical_accuracy: 0.4127 - loss: 1.4244 - val_categorical_accuracy: 0.3400 - val_loss: 4.4995 - learning_rate: 0.0100
# Epoch 11/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.3592 - loss: 1.4352
# Epoch 11: val_categorical_accuracy improved from 0.36000 to 0.37000, saving model to model_init_2025-02-1007_31_04.764953/model-00011-1.34825-0.39216-4.54949-0.37000.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 130s 12s/step - categorical_accuracy: 0.3620 - loss: 1.4279 - val_categorical_accuracy: 0.3700 - val_loss: 4.5495 - learning_rate: 0.0100
# Epoch 12/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.4691 - loss: 1.1820
# Epoch 12: val_categorical_accuracy did not improve from 0.37000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 130s 12s/step - categorical_accuracy: 0.4666 - loss: 1.1871 - val_categorical_accuracy: 0.3300 - val_loss: 4.6481 - learning_rate: 0.0100
# Epoch 13/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.4962 - loss: 1.2407
# Epoch 13: val_categorical_accuracy did not improve from 0.37000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 132s 12s/step - categorical_accuracy: 0.4934 - loss: 1.2447 - val_categorical_accuracy: 0.2100 - val_loss: 4.6759 - learning_rate: 0.0100
# Epoch 14/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.4541 - loss: 1.2863
# Epoch 14: val_categorical_accuracy did not improve from 0.37000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 131s 12s/step - categorical_accuracy: 0.4555 - loss: 1.2905 - val_categorical_accuracy: 0.2700 - val_loss: 5.3458 - learning_rate: 0.0100
# Epoch 15/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.4829 - loss: 1.1721
# Epoch 15: val_categorical_accuracy did not improve from 0.37000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 130s 12s/step - categorical_accuracy: 0.4825 - loss: 1.1737 - val_categorical_accuracy: 0.3100 - val_loss: 5.5450 - learning_rate: 0.0100
# Epoch 16/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - categorical_accuracy: 0.4969 - loss: 1.1823
# Epoch 16: val_categorical_accuracy did not improve from 0.37000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 129s 12s/step - categorical_accuracy: 0.4987 - loss: 1.1792 - val_categorical_accuracy: 0.3200 - val_loss: 5.6355 - learning_rate: 0.0080
# Epoch 17/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.5541 - loss: 1.0171
# Epoch 17: val_categorical_accuracy did not improve from 0.37000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 130s 12s/step - categorical_accuracy: 0.5530 - loss: 1.0207 - val_categorical_accuracy: 0.3500 - val_loss: 4.8790 - learning_rate: 0.0080
# Epoch 18/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.5631 - loss: 1.0569
# Epoch 18: val_categorical_accuracy did not improve from 0.37000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 130s 12s/step - categorical_accuracy: 0.5620 - loss: 1.0615 - val_categorical_accuracy: 0.3600 - val_loss: 4.0848 - learning_rate: 0.0080
# Epoch 19/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.5688 - loss: 1.0800
# Epoch 19: val_categorical_accuracy did not improve from 0.37000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 130s 12s/step - categorical_accuracy: 0.5687 - loss: 1.0776 - val_categorical_accuracy: 0.3700 - val_loss: 4.6778 - learning_rate: 0.0080
# Epoch 20/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.5608 - loss: 1.0558
# Epoch 20: val_categorical_accuracy improved from 0.37000 to 0.42000, saving model to model_init_2025-02-1007_31_04.764953/model-00020-1.07228-0.54902-3.85653-0.42000.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 129s 12s/step - categorical_accuracy: 0.5598 - loss: 1.0572 - val_categorical_accuracy: 0.4200 - val_loss: 3.8565 - learning_rate: 0.0080
# Epoch 21/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - categorical_accuracy: 0.5875 - loss: 0.9919
# Epoch 21: val_categorical_accuracy did not improve from 0.42000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 128s 11s/step - categorical_accuracy: 0.5882 - loss: 0.9917 - val_categorical_accuracy: 0.4100 - val_loss: 4.3423 - learning_rate: 0.0080
# Epoch 22/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - categorical_accuracy: 0.5817 - loss: 0.9647
# Epoch 22: val_categorical_accuracy improved from 0.42000 to 0.43000, saving model to model_init_2025-02-1007_31_04.764953/model-00022-0.98071-0.57617-3.88041-0.43000.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 129s 12s/step - categorical_accuracy: 0.5812 - loss: 0.9660 - val_categorical_accuracy: 0.4300 - val_loss: 3.8804 - learning_rate: 0.0080
# Epoch 23/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.6323 - loss: 0.9314
# Epoch 23: val_categorical_accuracy did not improve from 0.43000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 129s 12s/step - categorical_accuracy: 0.6319 - loss: 0.9319 - val_categorical_accuracy: 0.4000 - val_loss: 4.5285 - learning_rate: 0.0080
# Epoch 24/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - categorical_accuracy: 0.6149 - loss: 0.9664
# Epoch 24: val_categorical_accuracy did not improve from 0.43000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 128s 12s/step - categorical_accuracy: 0.6151 - loss: 0.9663 - val_categorical_accuracy: 0.4100 - val_loss: 5.2779 - learning_rate: 0.0080
# Epoch 25/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.5944 - loss: 0.9808
# Epoch 25: val_categorical_accuracy did not improve from 0.43000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 131s 12s/step - categorical_accuracy: 0.5938 - loss: 0.9807 - val_categorical_accuracy: 0.4000 - val_loss: 4.4026 - learning_rate: 0.0080
# Epoch 26/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.5956 - loss: 0.9493
# Epoch 26: val_categorical_accuracy improved from 0.43000 to 0.45000, saving model to model_init_2025-02-1007_31_04.764953/model-00026-0.92570-0.61991-4.08301-0.45000.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 133s 12s/step - categorical_accuracy: 0.5976 - loss: 0.9473 - val_categorical_accuracy: 0.4500 - val_loss: 4.0830 - learning_rate: 0.0064
# Epoch 27/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.6408 - loss: 0.8274
# Epoch 27: val_categorical_accuracy did not improve from 0.45000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 129s 12s/step - categorical_accuracy: 0.6422 - loss: 0.8254 - val_categorical_accuracy: 0.4400 - val_loss: 4.0583 - learning_rate: 0.0064
# Epoch 28/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.6969 - loss: 0.7542
# Epoch 28: val_categorical_accuracy improved from 0.45000 to 0.49000, saving model to model_init_2025-02-1007_31_04.764953/model-00028-0.77320-0.69382-6.06396-0.49000.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 129s 12s/step - categorical_accuracy: 0.6967 - loss: 0.7558 - val_categorical_accuracy: 0.4900 - val_loss: 6.0640 - learning_rate: 0.0064
# Epoch 29/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.6376 - loss: 0.9022
# Epoch 29: val_categorical_accuracy did not improve from 0.49000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 130s 12s/step - categorical_accuracy: 0.6378 - loss: 0.8988 - val_categorical_accuracy: 0.4200 - val_loss: 7.1681 - learning_rate: 0.0064
# Epoch 30/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.6517 - loss: 0.8152
# Epoch 30: val_categorical_accuracy did not improve from 0.49000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 131s 12s/step - categorical_accuracy: 0.6527 - loss: 0.8158 - val_categorical_accuracy: 0.3900 - val_loss: 6.0831 - learning_rate: 0.0064
# Epoch 31/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.6457 - loss: 0.8735
# Epoch 31: val_categorical_accuracy did not improve from 0.49000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 130s 12s/step - categorical_accuracy: 0.6475 - loss: 0.8726 - val_categorical_accuracy: 0.4400 - val_loss: 6.3281 - learning_rate: 0.0051
# Epoch 32/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.6931 - loss: 0.7534
# Epoch 32: val_categorical_accuracy did not improve from 0.49000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 130s 12s/step - categorical_accuracy: 0.6911 - loss: 0.7596 - val_categorical_accuracy: 0.4200 - val_loss: 6.6121 - learning_rate: 0.0051
# Epoch 33/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.6911 - loss: 0.7485
# Epoch 33: val_categorical_accuracy improved from 0.49000 to 0.51000, saving model to model_init_2025-02-1007_31_04.764953/model-00033-0.74113-0.70890-6.69548-0.51000.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 130s 12s/step - categorical_accuracy: 0.6926 - loss: 0.7479 - val_categorical_accuracy: 0.5100 - val_loss: 6.6955 - learning_rate: 0.0051
# Epoch 34/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.7343 - loss: 0.7179
# Epoch 34: val_categorical_accuracy improved from 0.51000 to 0.54000, saving model to model_init_2025-02-1007_31_04.764953/model-00034-0.68259-0.74661-6.20861-0.54000.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 131s 12s/step - categorical_accuracy: 0.7353 - loss: 0.7150 - val_categorical_accuracy: 0.5400 - val_loss: 6.2086 - learning_rate: 0.0051
# Epoch 35/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.7506 - loss: 0.6653
# Epoch 35: val_categorical_accuracy did not improve from 0.54000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 131s 12s/step - categorical_accuracy: 0.7491 - loss: 0.6683 - val_categorical_accuracy: 0.4900 - val_loss: 6.4988 - learning_rate: 0.0051
# Epoch 36/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.7250 - loss: 0.7368
# Epoch 36: val_categorical_accuracy improved from 0.54000 to 0.56000, saving model to model_init_2025-02-1007_31_04.764953/model-00036-0.75159-0.72398-5.05615-0.56000.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 134s 12s/step - categorical_accuracy: 0.7249 - loss: 0.7380 - val_categorical_accuracy: 0.5600 - val_loss: 5.0561 - learning_rate: 0.0041
# Epoch 37/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.7411 - loss: 0.6506
# Epoch 37: val_categorical_accuracy improved from 0.56000 to 0.58000, saving model to model_init_2025-02-1007_31_04.764953/model-00037-0.64094-0.74208-4.95523-0.58000.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 132s 12s/step - categorical_accuracy: 0.7412 - loss: 0.6498 - val_categorical_accuracy: 0.5800 - val_loss: 4.9552 - learning_rate: 0.0041
# Epoch 38/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.7513 - loss: 0.6477
# Epoch 38: val_categorical_accuracy did not improve from 0.58000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 129s 12s/step - categorical_accuracy: 0.7521 - loss: 0.6485 - val_categorical_accuracy: 0.5700 - val_loss: 5.3712 - learning_rate: 0.0041
# Epoch 39/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.7482 - loss: 0.6825
# Epoch 39: val_categorical_accuracy did not improve from 0.58000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 130s 12s/step - categorical_accuracy: 0.7487 - loss: 0.6818 - val_categorical_accuracy: 0.5100 - val_loss: 5.3047 - learning_rate: 0.0041
# Epoch 40/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.7731 - loss: 0.6054
# Epoch 40: val_categorical_accuracy did not improve from 0.58000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 129s 12s/step - categorical_accuracy: 0.7721 - loss: 0.6064 - val_categorical_accuracy: 0.5800 - val_loss: 5.3930 - learning_rate: 0.0041
# Epoch 41/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.7575 - loss: 0.5944
# Epoch 41: val_categorical_accuracy did not improve from 0.58000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 130s 12s/step - categorical_accuracy: 0.7581 - loss: 0.5937 - val_categorical_accuracy: 0.5700 - val_loss: 5.3569 - learning_rate: 0.0033
# Epoch 42/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.7311 - loss: 0.6528
# Epoch 42: val_categorical_accuracy improved from 0.58000 to 0.62000, saving model to model_init_2025-02-1007_31_04.764953/model-00042-0.63791-0.75113-5.24801-0.62000.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 129s 12s/step - categorical_accuracy: 0.7328 - loss: 0.6515 - val_categorical_accuracy: 0.6200 - val_loss: 5.2480 - learning_rate: 0.0033
# Epoch 43/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - categorical_accuracy: 0.7761 - loss: 0.5823
# Epoch 43: val_categorical_accuracy did not improve from 0.62000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 129s 12s/step - categorical_accuracy: 0.7754 - loss: 0.5833 - val_categorical_accuracy: 0.6200 - val_loss: 5.0142 - learning_rate: 0.0033
# Epoch 44/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.7741 - loss: 0.5493
# Epoch 44: val_categorical_accuracy did not improve from 0.62000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 133s 12s/step - categorical_accuracy: 0.7750 - loss: 0.5490 - val_categorical_accuracy: 0.6100 - val_loss: 5.0723 - learning_rate: 0.0033
# Epoch 45/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.7836 - loss: 0.5928
# Epoch 45: val_categorical_accuracy improved from 0.62000 to 0.66000, saving model to model_init_2025-02-1007_31_04.764953/model-00045-0.59818-0.78733-4.63720-0.66000.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 131s 12s/step - categorical_accuracy: 0.7839 - loss: 0.5933 - val_categorical_accuracy: 0.6600 - val_loss: 4.6372 - learning_rate: 0.0033
# Epoch 46/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.8214 - loss: 0.4884
# Epoch 46: val_categorical_accuracy did not improve from 0.66000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 131s 12s/step - categorical_accuracy: 0.8199 - loss: 0.4909 - val_categorical_accuracy: 0.6100 - val_loss: 4.8994 - learning_rate: 0.0026
# Epoch 47/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.8137 - loss: 0.5366
# Epoch 47: val_categorical_accuracy did not improve from 0.66000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 129s 12s/step - categorical_accuracy: 0.8130 - loss: 0.5380 - val_categorical_accuracy: 0.6500 - val_loss: 4.8780 - learning_rate: 0.0026
# Epoch 48/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.7866 - loss: 0.5968
# Epoch 48: val_categorical_accuracy did not improve from 0.66000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 130s 12s/step - categorical_accuracy: 0.7882 - loss: 0.5926 - val_categorical_accuracy: 0.6300 - val_loss: 4.6859 - learning_rate: 0.0026
# Epoch 49/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.8026 - loss: 0.5176
# Epoch 49: val_categorical_accuracy did not improve from 0.66000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 131s 12s/step - categorical_accuracy: 0.8035 - loss: 0.5161 - val_categorical_accuracy: 0.6300 - val_loss: 4.6490 - learning_rate: 0.0026
# Epoch 50/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.7702 - loss: 0.6309
# Epoch 50: val_categorical_accuracy did not improve from 0.66000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 130s 12s/step - categorical_accuracy: 0.7728 - loss: 0.6230 - val_categorical_accuracy: 0.6400 - val_loss: 4.5928 - learning_rate: 0.0026
# Epoch 51/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.8450 - loss: 0.4325
# Epoch 51: val_categorical_accuracy did not improve from 0.66000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 129s 12s/step - categorical_accuracy: 0.8437 - loss: 0.4360 - val_categorical_accuracy: 0.6300 - val_loss: 4.7140 - learning_rate: 0.0021
# Epoch 52/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.7956 - loss: 0.5462
# Epoch 52: val_categorical_accuracy did not improve from 0.66000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 132s 12s/step - categorical_accuracy: 0.7960 - loss: 0.5463 - val_categorical_accuracy: 0.6500 - val_loss: 4.4832 - learning_rate: 0.0021
# Epoch 53/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.7900 - loss: 0.4946
# Epoch 53: val_categorical_accuracy did not improve from 0.66000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 131s 12s/step - categorical_accuracy: 0.7913 - loss: 0.4943 - val_categorical_accuracy: 0.6200 - val_loss: 4.6018 - learning_rate: 0.0021
# Epoch 54/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.8268 - loss: 0.4283
# Epoch 54: val_categorical_accuracy did not improve from 0.66000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 131s 12s/step - categorical_accuracy: 0.8270 - loss: 0.4297 - val_categorical_accuracy: 0.6300 - val_loss: 4.6689 - learning_rate: 0.0021
# Epoch 55/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.7849 - loss: 0.5390
# Epoch 55: val_categorical_accuracy improved from 0.66000 to 0.67000, saving model to model_init_2025-02-1007_31_04.764953/model-00055-0.52700-0.79789-4.69625-0.67000.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 132s 12s/step - categorical_accuracy: 0.7860 - loss: 0.5380 - val_categorical_accuracy: 0.6700 - val_loss: 4.6963 - learning_rate: 0.0021
# Epoch 56/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.7972 - loss: 0.5344
# Epoch 56: val_categorical_accuracy did not improve from 0.67000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 134s 12s/step - categorical_accuracy: 0.7986 - loss: 0.5319 - val_categorical_accuracy: 0.6500 - val_loss: 4.5549 - learning_rate: 0.0017
# Epoch 57/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.8454 - loss: 0.4312
# Epoch 57: val_categorical_accuracy did not improve from 0.67000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 134s 12s/step - categorical_accuracy: 0.8434 - loss: 0.4358 - val_categorical_accuracy: 0.6500 - val_loss: 4.6953 - learning_rate: 0.0017
# Epoch 58/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.8729 - loss: 0.3992
# Epoch 58: val_categorical_accuracy did not improve from 0.67000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 132s 12s/step - categorical_accuracy: 0.8709 - loss: 0.4047 - val_categorical_accuracy: 0.6400 - val_loss: 4.6219 - learning_rate: 0.0017
# Epoch 59/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.8590 - loss: 0.4141
# Epoch 59: val_categorical_accuracy did not improve from 0.67000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 133s 12s/step - categorical_accuracy: 0.8584 - loss: 0.4156 - val_categorical_accuracy: 0.6500 - val_loss: 4.5638 - learning_rate: 0.0017
# Epoch 60/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.8212 - loss: 0.5092
# Epoch 60: val_categorical_accuracy did not improve from 0.67000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 134s 12s/step - categorical_accuracy: 0.8224 - loss: 0.5058 - val_categorical_accuracy: 0.6200 - val_loss: 4.7016 - learning_rate: 0.0017
# Epoch 61/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.8115 - loss: 0.4844
# Epoch 61: val_categorical_accuracy did not improve from 0.67000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 133s 12s/step - categorical_accuracy: 0.8121 - loss: 0.4840 - val_categorical_accuracy: 0.6400 - val_loss: 4.7357 - learning_rate: 0.0013
# Epoch 62/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.8421 - loss: 0.4529
# Epoch 62: val_categorical_accuracy did not improve from 0.67000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 131s 12s/step - categorical_accuracy: 0.8410 - loss: 0.4526 - val_categorical_accuracy: 0.6400 - val_loss: 4.6883 - learning_rate: 0.0013
# Epoch 63/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.8753 - loss: 0.3782
# Epoch 63: val_categorical_accuracy did not improve from 0.67000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 131s 12s/step - categorical_accuracy: 0.8732 - loss: 0.3806 - val_categorical_accuracy: 0.6400 - val_loss: 4.7704 - learning_rate: 0.0013
# Epoch 64/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.8550 - loss: 0.3817
# Epoch 64: val_categorical_accuracy did not improve from 0.67000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 130s 12s/step - categorical_accuracy: 0.8547 - loss: 0.3847 - val_categorical_accuracy: 0.6400 - val_loss: 4.6338 - learning_rate: 0.0013
# Epoch 65/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.8620 - loss: 0.3765
# Epoch 65: val_categorical_accuracy did not improve from 0.67000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 130s 12s/step - categorical_accuracy: 0.8608 - loss: 0.3802 - val_categorical_accuracy: 0.6300 - val_loss: 4.6700 - learning_rate: 0.0013
# Epoch 65: early stopping

# %%
# Plot the accuracy graph and save to a file
hist = model.history.history

fig, axs = plt.subplots(1,2, figsize=(15,3))
axs[0].plot(hist['categorical_accuracy'])
axs[0].plot(hist['val_categorical_accuracy'])
axs[0].set_title('model accuracy')
axs[0].set_ylabel('accuracy')
axs[0].set_xlabel('epoch')
axs[0].legend(['train', 'test'], loc='upper left')

axs[1].plot(hist['loss'])
axs[1].plot(hist['val_loss'])
axs[1].set_title('model loss')
axs[1].set_ylabel('loss')
axs[1].set_xlabel('epoch')
axs[1].legend(['train', 'test'], loc='upper left')

fig.savefig(model_name+"graph.png")
# plt.show();

# %%
# saves the model summary to a file
with open(model_name+'model_summary.txt', 'w') as f:
    model.summary(print_fn=lambda x: f.write(x + '\n'))
    f.write(str([hp_epoch,hp_batch_size,hp_img_cnt,hp_lr,hp_reducelr,hp_y,hp_z])+ '\n')

# saves the model plot to a file        
keras.utils.plot_model(
    model, to_file=model_name+"model.png", show_shapes=True, show_dtype=True, show_layer_names=True,
    rankdir="TB", expand_nested=True, dpi=200, show_layer_activations=True, show_trainable=True)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
# Post Processing Steps
if env == 1: # direct download from colab
    files.download('model.keras')
  
elif env == 2: 
    # do not forget to move the model to the drive output folder
    shutil.move(model_name, drive_base+'/outputs')
    
elif env == 3: #kaggle
    if not os.path.exists('outputs'):
        os.mkdir('outputs')
        
    if os.path.exists('outputs'):
        files_paths = glob.glob('model_init*', dir_fd='./', recursive=True)
        for path in files_paths:
            shutil.move(path , 'outputs')
            
        pattern = '**/*.keras'
        files_paths = glob.glob(pattern, root_dir='outputs/', recursive=True)
    
        with open('outputs/'+model_name+'model_summary.txt', 'a') as f:
            f.write(str(files_paths))
    
        match_op = [match(r'model_init_[-_.\d]+/model[-\d\.]*(\d{5}).keras', path ) for path in files_paths]
    
        accuracy_list = [i.group(1) for i in match_op]
        accuracy_list.sort(reverse=True)

        for item in accuracy_list[4:]:
            for path in files_paths:
                if item in path:
                    os.remove('outputs/'+path)
                
        #At the end of the session, zip the output folder
        # shutil.make_archive('model_output_latest', 'zip', '/kaggle/working/outputs/')    
        # !rm -rf outputs/ 
else:
    shutil.move(model_name , 'outputs')

end_time = time.time()
total_time = end_time - start_time 
print(f'{total_time}')
# Out:
# 8622.638375043869
